# %% [markdown]
# # **SET-UP**
#
# In this section, the relavant libraries are imported, and the training, validation and test datasets are prepared.
#
# If the notebook is running on Google Colab, the data can be downloaded to the environment by running the corresponding cell.

# %%
# imports

import os
import sys
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional
from torchvision import transforms

import matplotlib.pyplot as plt
import numpy as np

import cv2
from PIL import Image

# %% [markdown]
# ### Download Data into Google Colab Environment
#
# This cell should only be executed if the notebook is running on Google Colab.
#
# If the notebook is running locally with the data already situated in the correct directory, this cell block should **not** be run.

# %%
# download if zip files not already downloaded
if not os.path.exists('data.zip'):
    # !gdown '1KCEr8wD4vGuYhop8ShshLFPnx-3wzeSW'
else:
    print('data.zip already exists')

# unzip if folders don't already exist
if not os.path.exists('data'):
    # !unzip -qq data.zip
    # !rm data.zip
else:
    print('data folder already exists')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1KCEr8wD4vGuYhop8ShshLFPnx-3wzeSW
# From (redirected): https://drive.google.com/uc?id=1KCEr8wD4vGuYhop8ShshLFPnx-3wzeSW&confirm=t&uuid=911916c4-bf16-421d-9f75-313b011696df
# To: /content/data.zip
# 100% 289M/289M [00:02<00:00, 136MB/s]

# %%
# download if zip files not already downloaded
if not os.path.exists('utils.zip'):
    # !gdown '1x402dUiBIKfrkBgzd-nbnZDdP1a_tTs4'
else:
    print('utils.zip already exists')

# unzip if folders don't already exist
if not os.path.exists('utils'):
    # !unzip -qq utils.zip
    # !rm utils.zip
else:
    print('utils folder already exists')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1x402dUiBIKfrkBgzd-nbnZDdP1a_tTs4
# To: /content/utils.zip
# 100% 1.79k/1.79k [00:00<00:00, 8.85MB/s]

# %%
# download if zip files not already downloaded
if not os.path.exists('depth_estimation.zip'):
    # !gdown '1aNww-oYs-eObTImT923rFejQDDLsfOI6'
else:
    print('depth_estimation.zip already exists')

# unzip if folders don't already exist
if not os.path.exists('depth_estimation'):
    # !unzip -qq depth_estimation.zip
    # !rm depth_estimation.zip
else:
    print('depth_estimation folder already exists')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1aNww-oYs-eObTImT923rFejQDDLsfOI6
# From (redirected): https://drive.google.com/uc?id=1aNww-oYs-eObTImT923rFejQDDLsfOI6&confirm=t&uuid=9f3a9f08-4061-4c4a-b0e9-7798a97f1142
# To: /content/depth_estimation.zip
# 100% 55.4M/55.4M [00:00<00:00, 106MB/s]

# %% [markdown]
# ## Constructing Datasets

# %% [markdown]
# Informally experimenting with various batch sizes,demonstrated that a batch size of four yielded the best results.

# %%
# batch size
B = 4

# %% [markdown]
# The appropriate transformations can be applied for training, validation and test data. The dataset is split into 60% for training data, 10% for validation data, and 30% for test data.

# %%
from torch.utils.data import random_split, DataLoader
from utils.seq_dataset import SeqDataset
from utils.data_management import get_transform, initialize_loader

# set up dataset
dataset = SeqDataset(root_dir='data', transform=None)

# picking out the sizes
train_size = int(0.6 * len(dataset))              # 60% for training
val_size = int(0.1 * len(dataset))                # 10% for validation
test_size = len(dataset) - train_size - val_size  # 30 for testing

# split the dataset into train, validation, and test sets
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# dataloaders
train_loader = initialize_loader(train_dataset, get_transform("train"), B, True)
val_loader = initialize_loader(val_dataset, get_transform("validation"), B, False)
test_loader = initialize_loader(test_dataset, get_transform("test"), B, False)

# %% [markdown]
# ### Visualize Data

# %% [markdown]
# This cell can be optionally executed to visualize the structure of the dataset.

# %%
tgt, [s1, s2] = train_dataset[10]
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title("Target - 1")
plt.imshow(s1.permute(1, 2, 0).numpy())
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Target")
plt.imshow(tgt.permute(1, 2, 0).numpy())
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title("Target + 1")
plt.imshow(s2.permute(1, 2, 0).numpy())
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.980906..2.5528543].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.980906..2.5702832].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9980307..2.5877128].

# %% [markdown]
# # **TRAINING**

# %%
from object_detector import ObjSegmentation
from segmentation_trainer import SegmentationTrainer
from utils.visual_helpers import plot_train_loss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Load Pretrained Models

# %%
# load pretrained dino for backbone feature detector
dino = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14').to(device)
feat_dim = 768  # fixed value
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitb14_pretrain.pth
# 100%|██████████| 330M/330M [00:01<00:00, 220MB/s]

# %%
from depth_estimation.depth_net import DepthNet
from depth_estimation.pose_net import PoseNet

depth_net = DepthNet().to(device)
pose_net = PoseNet().to(device)

depth_net.load_state_dict(torch.load("depth_estimation/weights/depth_D_weights.pth", map_location=torch.device('cpu')))
pose_net.load_state_dict(torch.load("depth_estimation/weights/pose_D_weights.pth", map_location=torch.device('cpu')))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 189MB/s]
# <All keys matched successfully>

# %% [markdown]
# ## Version A: Solo Training the Object Segmentation Module

# %% [markdown]
# ### LR = 1e-4

# %%
solo_obj_detector_a = ObjSegmentation(feat_dim).to(device)
optimizer = torch.optim.Adam(solo_obj_detector_a.parameters(), lr=1e-4)
solo_trainer_a = SegmentationTrainer(solo_obj_detector_a, optimizer, train_loader, device, dino=dino, epochs=50)

# %%
solo_trainer_a.train()
# Out:
# EPOCH 1 -----------------------------
# [average loss: 0.7445]
#
# EPOCH 2 -----------------------------
# [average loss: 0.7364]
#
# EPOCH 3 -----------------------------
# [average loss: 0.7353]
#
# EPOCH 4 -----------------------------
# [average loss: 0.7347]
#
# EPOCH 5 -----------------------------
# [average loss: 0.7341]
#
# EPOCH 6 -----------------------------
# [average loss: 0.7339]
#
# EPOCH 7 -----------------------------
# [average loss: 0.7337]
#
# EPOCH 8 -----------------------------
# [average loss: 0.7335]
#
# EPOCH 9 -----------------------------
# [average loss: 0.7335]
#
# EPOCH 10 -----------------------------
# [average loss: 0.7332]
#
# EPOCH 11 -----------------------------
# [average loss: 0.7331]
#
# EPOCH 12 -----------------------------
# [average loss: 0.7332]
#
# EPOCH 13 -----------------------------
# [average loss: 0.7329]
#
# EPOCH 14 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 15 -----------------------------
# [average loss: 0.7327]
#
# EPOCH 16 -----------------------------
# [average loss: 0.7327]
#
# EPOCH 17 -----------------------------
# [average loss: 0.7327]
#
# EPOCH 18 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 19 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 20 -----------------------------
# [average loss: 0.7325]
#
# EPOCH 21 -----------------------------
# [average loss: 0.7324]
#
# EPOCH 22 -----------------------------
# [average loss: 0.7325]
#
# EPOCH 23 -----------------------------
# [average loss: 0.7325]
#
# EPOCH 24 -----------------------------
# [average loss: 0.7324]
#
# EPOCH 25 -----------------------------
# [average loss: 0.7323]
#
# EPOCH 26 -----------------------------
# [average loss: 0.7323]
#
# EPOCH 27 -----------------------------
# [average loss: 0.7323]
#
# EPOCH 28 -----------------------------
# [average loss: 0.7323]
#
# EPOCH 29 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 30 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 31 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 32 -----------------------------
# [average loss: 0.7323]
#
# EPOCH 33 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 34 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 35 -----------------------------
# [average loss: 0.7321]
#
# EPOCH 36 -----------------------------
# [average loss: 0.7321]
#
# EPOCH 37 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 38 -----------------------------
# [average loss: 0.7322]
#
# EPOCH 39 -----------------------------
# [average loss: 0.7321]
#
# EPOCH 40 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 41 -----------------------------
# [average loss: 0.7321]
#
# EPOCH 42 -----------------------------
# [average loss: 0.7321]
#
# EPOCH 43 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 44 -----------------------------
# [average loss: 0.7321]
#
# EPOCH 45 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 46 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 47 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 48 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 49 -----------------------------
# [average loss: 0.7320]
#
# EPOCH 50 -----------------------------
# [average loss: 0.7320]

# %% [markdown]
# ### LR = 1e-3

# %%
solo_obj_detector_b = ObjSegmentation(feat_dim).to(device)
optimizer = torch.optim.Adam(solo_obj_detector_b.parameters(), lr=1e-3)
solo_trainer_b = SegmentationTrainer(solo_obj_detector_b, optimizer, train_loader, device, dino=dino, epochs=50)

# %%
solo_trainer_b.train()
# Out:
# EPOCH 1 -----------------------------
# [average loss: 0.7457]
#
# EPOCH 2 -----------------------------
# [average loss: 0.7365]
#
# EPOCH 3 -----------------------------
# [average loss: 0.7352]
#
# EPOCH 4 -----------------------------
# [average loss: 0.7348]
#
# EPOCH 5 -----------------------------
# [average loss: 0.7342]
#
# EPOCH 6 -----------------------------
# [average loss: 0.7341]
#
# EPOCH 7 -----------------------------
# [average loss: 0.7339]
#
# EPOCH 8 -----------------------------
# [average loss: 0.7341]
#
# EPOCH 9 -----------------------------
# [average loss: 0.7339]
#
# EPOCH 10 -----------------------------
# [average loss: 0.7336]
#
# EPOCH 11 -----------------------------
# [average loss: 0.7336]
#
# EPOCH 12 -----------------------------
# [average loss: 0.7336]
#
# EPOCH 13 -----------------------------
# [average loss: 0.7333]
#
# EPOCH 14 -----------------------------
# [average loss: 0.7336]
#
# EPOCH 15 -----------------------------
# [average loss: 0.7334]
#
# EPOCH 16 -----------------------------
# [average loss: 0.7332]
#
# EPOCH 17 -----------------------------
# [average loss: 0.7332]
#
# EPOCH 18 -----------------------------
# [average loss: 0.7331]
#
# EPOCH 19 -----------------------------
# [average loss: 0.7333]
#
# EPOCH 20 -----------------------------
# [average loss: 0.7331]
#
# EPOCH 21 -----------------------------
# [average loss: 0.7332]
#
# EPOCH 22 -----------------------------
# [average loss: 0.7331]
#
# EPOCH 23 -----------------------------
# [average loss: 0.7332]
#
# EPOCH 24 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 25 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 26 -----------------------------
# [average loss: 0.7329]
#
# EPOCH 27 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 28 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 29 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 30 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 31 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 32 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 33 -----------------------------
# [average loss: 0.7329]
#
# EPOCH 34 -----------------------------
# [average loss: 0.7329]
#
# EPOCH 35 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 36 -----------------------------
# [average loss: 0.7327]
#
# EPOCH 37 -----------------------------
# [average loss: 0.7327]
#
# EPOCH 38 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 39 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 40 -----------------------------
# [average loss: 0.7328]
#
# EPOCH 41 -----------------------------
# [average loss: 0.7330]
#
# EPOCH 42 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 43 -----------------------------
# [average loss: 0.7327]
#
# EPOCH 44 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 45 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 46 -----------------------------
# [average loss: 0.7325]
#
# EPOCH 47 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 48 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 49 -----------------------------
# [average loss: 0.7326]
#
# EPOCH 50 -----------------------------
# [average loss: 0.7326]

# %% [markdown]
# ### LR = 1e-2

# %%
solo_obj_detector_c = ObjSegmentation(feat_dim).to(device)
optimizer = torch.optim.Adam(solo_obj_detector_c.parameters(), lr=1e-2)
solo_trainer_c = SegmentationTrainer(solo_obj_detector_c, optimizer, train_loader, device, dino=dino, epochs=50)

# %%
solo_trainer_c.train()
# Out:
# EPOCH 1 -----------------------------
# [average loss: 1.1932]
#
# EPOCH 2 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 3 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 4 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 5 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 6 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 7 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 8 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 9 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 10 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 11 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 12 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 13 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 14 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 15 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 16 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 17 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 18 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 19 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 20 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 21 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 22 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 23 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 24 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 25 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 26 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 27 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 28 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 29 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 30 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 31 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 32 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 33 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 34 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 35 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 36 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 37 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 38 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 39 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 40 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 41 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 42 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 43 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 44 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 45 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 46 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 47 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 48 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 49 -----------------------------
# [average loss: 1.1941]
#
# EPOCH 50 -----------------------------
# [average loss: 1.1941]

# %% [markdown]
# ## Version B: Training with a Pretrained Depth Estimator

# %% [markdown]
# ### LR = 5e-4

# %%
wd_obj_detector_a = ObjSegmentation(feat_dim).to(device)
optimizer = torch.optim.Adam(wd_obj_detector_a.parameters(), lr=5e-4)
wd_trainer_a = SegmentationTrainer(wd_obj_detector_a, optimizer, train_loader, device, depth_net=depth_net, dino=dino, epochs=50)

# %%
wd_trainer_a.train()
# Out:
# EPOCH 1 -----------------------------
# [average loss: 0.7496]
#
# EPOCH 2 -----------------------------
# [average loss: 0.7425]
#
# EPOCH 3 -----------------------------
# [average loss: 0.7416]
#
# EPOCH 4 -----------------------------
# [average loss: 0.7412]
#
# EPOCH 5 -----------------------------
# [average loss: 0.7410]
#
# EPOCH 6 -----------------------------
# [average loss: 0.7408]
#
# EPOCH 7 -----------------------------
# [average loss: 0.7406]
#
# EPOCH 8 -----------------------------
# [average loss: 0.7405]
#
# EPOCH 9 -----------------------------
# [average loss: 0.7404]
#
# EPOCH 10 -----------------------------
# [average loss: 0.7403]
#
# EPOCH 11 -----------------------------
# [average loss: 0.7403]
#
# EPOCH 12 -----------------------------
# [average loss: 0.7402]
#
# EPOCH 13 -----------------------------
# [average loss: 0.7402]
#
# EPOCH 14 -----------------------------
# [average loss: 0.7401]
#
# EPOCH 15 -----------------------------
# [average loss: 0.7401]
#
# EPOCH 16 -----------------------------
# [average loss: 0.7401]
#
# EPOCH 17 -----------------------------
# [average loss: 0.7401]
#
# EPOCH 18 -----------------------------
# [average loss: 0.7400]
#
# EPOCH 19 -----------------------------
# [average loss: 0.7400]
#
# EPOCH 20 -----------------------------
# [average loss: 0.7400]

# %% [markdown]
# ### LR = 5e-3

# %%
wd_obj_detector_b = ObjSegmentation(feat_dim).to(device)
optimizer = torch.optim.Adam(wd_obj_detector_b.parameters(), lr=5e-3)
wd_trainer_b = SegmentationTrainer(wd_obj_detector_b, optimizer, train_loader, device, depth_net=depth_net, dino=dino, epochs=50)

# %%
wd_trainer_b.train()

# %% [markdown]
# ### LR = 1e-2

# %%
wd_obj_detector_c = ObjSegmentation(feat_dim).to(device)
optimizer = torch.optim.Adam(wd_obj_detector_c.parameters(), lr=5e-2)
wd_trainer_c = SegmentationTrainer(wd_obj_detector_c, optimizer, train_loader, device, depth_net=depth_net, dino=dino, epochs=50)

# %%
wd_trainer_c.train()

# %% [markdown]
# ## Version C: Joint Training with Untrained Depth Estimator

# %% [markdown]
# ### LR = 1e-3

# %% [markdown]
# ### LR = 5e-3

# %% [markdown]
# ### LR = 1e-2

# %% [markdown]
# ## Analysis: Pretrained vs Joint Training Loss Over Epochs

# %% [markdown]
# #### Version A: Solo

# %% [markdown]
# ##### **LR = 1e-4**

# %%
plot_train_loss(solo_trainer_a, 50)

# %% [markdown]
# ##### **LR = 1e-3**

# %%
plot_train_loss(solo_trainer_b, 50)

# %% [markdown]
# ##### **LR = 1e-2**
#
# This learning rate is too large

# %%
plot_train_loss(solo_trainer_c, 50)

# %% [markdown]
# #### Version B: With Pretrained Depth

# %% [markdown]
# ##### **LR = 5e-4**

# %%
plot_train_loss(wd_trainer_a, 50)

# %% [markdown]
# ##### **LR = 5e-3**

# %%
plot_train_loss(wd_trainer_b, 50)

# %% [markdown]
# ##### **LR = 1e-2**

# %%
plot_train_loss(wd_trainer_c, 50)

# %% [markdown]
# ### Version C: Joint

# %% [markdown]
# ##### **LR = 1e-3**

# %%
plot_train_loss(solo_trainer_a, 50)

# %% [markdown]
# ##### **LR = 5e-3**

# %%
plot_train_loss(solo_trainer_a, 50)

# %% [markdown]
# ##### **LR = 1e-2**

# %%
plot_train_loss(solo_trainer_a, 50)

# %% [markdown]
# # **EVALUATION**

# %% [markdown]
# ##### Helper Functions

# %%
from segmentation_trainer import extract_features

with torch.no_grad():
    for tgt, _ in val_loader:
        tgt = tgt.to(device)
        image_np = tgt[0].detach().cpu().permute(1, 2, 0).numpy().clip(0, 1)
        break

def show_masks(masks):
    fig, axes = plt.subplots(2, 5, figsize=(20, 10))
    axes = axes.flatten()

    for ax in axes[1:]:
        ax.axis("off")

    for k in range(10):
        mask_np = masks[0, k].detach().cpu().numpy()
        axes[k].imshow(mask_np, cmap='gray')
        axes[k].set_title(f"Mask {k+1}")
        axes[k].axis("off")

    plt.tight_layout()
    plt.show()


def val_results(obj_seg):
    obj_seg.eval()

    feats = extract_features(dino, tgt)
    masks = obj_seg(feats)

    show_masks(masks)

# %% [markdown]
# #### Sample Image

# %%
plt.imshow(image_np)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Version A: Solo Trained

# %% [markdown]
# ### LR = 1e-4

# %%
val_results(solo_obj_detector_a)

# %% [markdown]
# ### LR = 1e-3

# %%
val_results(solo_obj_detector_b)

# %% [markdown]
# ### LR = 1e-2

# %%
val_results(solo_obj_detector_c)

# %% [markdown]
# ## Version B: Trained with Pretrained Depth Estimator

# %% [markdown]
# ### LR = 5e-4

# %%
val_results(wd_obj_detector_a)

# %% [markdown]
# ### LR = 5e-3

# %%
val_results(wd_obj_detector_b)

# %% [markdown]
# ### LR = 1e-2

# %%
val_results(wd_obj_detector_c)

# %% [markdown]
# ## Version C: Joint Trained

# %% [markdown]
# ### LR = 1e-3

# %% [markdown]
# ### LR = 5e-3

# %% [markdown]
# ### LR = 1e-2
